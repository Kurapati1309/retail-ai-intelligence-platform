# %% [markdown]
# # EDA (Exploratory Data Analysis)
# Run data generation first: `python src/data/generate_synthetic.py`
# Then preprocess: `python -m src.data.preprocess`

# %%
import pandas as pd
customers = pd.read_csv('../data/raw/customers.csv')
txns = pd.read_csv('../data/raw/transactions.csv')
reviews = pd.read_csv('../data/raw/reviews.csv')
customers.head(), txns.head(), reviews.head()
