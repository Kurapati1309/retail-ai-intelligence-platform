# %% [markdown]
# # NLP Features
# This notebook demonstrates generating text embeddings for customer reviews.

# %%
import pandas as pd
from src.features.text_embeddings import TextEmbedder
reviews = pd.read_csv('../data/processed/reviews_clean.csv')
embedder = TextEmbedder('distilbert-base-uncased')
vecs = embedder.encode(reviews['review_text'].tolist()[:100])
vecs.shape
